# %% [markdown]
# <p><a href="https://www.asu.edu.eg/"><img align="right" src="https://ums.asu.edu.eg/images/logo.png" width="100" /></a></p>
# <div align=left>
# <h1>
#   Body Signal of Smoking 🚭
# </h1>
#     <h5>
#         Data Analytics project
#     </h5>
# </div>
# <br>
# <br>

# %% [markdown]
# ## Introduction
# This dataset is a collection of basic health biological signal data.
# The goal is to determine the presence or absence of smoking through bio-signals.

# %% [markdown]
# ## All libraries we need through the notebook

# %%
import pandas as pd  #for data manipulation operations
import numpy as np  #for numeric operations on data
import seaborn as sns  #for data visualization operations
import matplotlib.pyplot as plt  #for data visualization operations
from sklearn.preprocessing import LabelEncoder # for encoding
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler #for standardization
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from termcolor import colored
import scipy.stats as st
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

# %matplotlib inline
# to ignore warnings
import warnings
warnings.filterwarnings("ignore")

#to see model hyperparameters
from sklearn import set_config
set_config(print_changed_only = False)

# to show all columns
pd.set_option('display.max_columns', 30)

print(colored("\nLIBRARIES WERE SUCCESFULLY IMPORTED...", color = "green", attrs = ["dark", "bold"]))
# Out:
# LIBRARIES WERE SUCCESFULLY IMPORTED...

# %% [markdown]
# ## Reading the dataset

# %%
df = pd.read_csv('smoking.csv')
df.head(n = 10).style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_20552_row0_col0, #T_20552_row0_col4, #T_20552_row0_col8, #T_20552_row0_col9, #T_20552_row0_col18, #T_20552_row0_col24, #T_20552_row1_col4, #T_20552_row1_col7, #T_20552_row1_col8, #T_20552_row1_col9, #T_20552_row1_col18, #T_20552_row1_col19, #T_20552_row1_col24, #T_20552_row2_col4, #T_20552_row2_col5, #T_20552_row2_col8, #T_20552_row2_col9, #T_20552_row2_col18, #T_20552_row2_col24, #T_20552_row3_col8, #T_20552_row3_col9, #T_20552_row3_col10, #T_20552_row3_col11, #T_20552_row3_col18, #T_20552_row3_col24, #T_20552_row4_col4, #T_20552_row4_col8, #T_20552_row4_col9, #T_20552_row4_col12, #T_20552_row4_col13, #T_20552_row4_col16, #T_20552_row4_col17, #T_20552_row4_col18, #T_20552_row4_col19, #T_20552_row4_col20, #T_20552_row4_col21, #T_20552_row4_col24, #T_20552_row5_col2, #T_20552_row5_col8, #T_20552_row5_col9, #T_20552_row5_col18, #T_20552_row5_col24, #T_20552_row6_col4, #T_20552_row6_col8, #T_20552_row6_col9, #T_20552_row6_col18, #T_20552_row7_col8, #T_20552_row7_col9, #T_20552_row7_col15, #T_20552_row7_col18, #T_20552_row7_col24, #T_20552_row8_col3, #T_20552_row8_col4, #T_20552_row8_col6, #T_20552_row8_col8, #T_20552_row8_col9, #T_20552_row8_col14, #T_20552_row8_col18, #T_20552_row8_col22, #T_20552_row8_col24, #T_20552_row9_col8, #T_20552_row9_col9, #T_20552_row9_col18, #T_20552_row9_col24 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_20552_row0_col2, #T_20552_row1_col2, #T_20552_row3_col2, #T_20552_row4_col0, #T_20552_row4_col2, #T_20552_row6_col2, #T_20552_row9_col14 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_20552_row0_col3, #T_20552_row4_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_20552_row0_col5, #T_20552_row0_col14 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_20552_row0_col6, #T_20552_row5_col6, #T_20552_row7_col6 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_20552_row8_col12

# %%
# Drop ID
df = df.drop("ID", axis = 1)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental caries',
#        'tartar', 'smoking'],
#       dtype='object')

# %% [markdown]
# ####
# #### We see thet the dataset attributes are divided into dependent and independent attributes.
# #### The inedependent attributes are :
# - ID : index
# - gender
# - age : 5-years gap
# - height(cm)
# - weight(kg)
# - waist(cm) : Waist circumference length
# - eyesight(left)
# - eyesight(right)
# - hearing(left)
# - hearing(right)
# - systolic : Blood pressure (measures the pressure in your arteries when your heart beats)
# - relaxation : Blood pressure
# - fasting blood sugar
# - Cholesterol : total
# - triglyceride
# - HDL : cholesterol type
# - LDL : cholesterol type
# - hemoglobin
# - Urine protein
# - serum creatinine
# - AST : glutamic oxaloacetic transaminase type
# - ALT : glutamic oxaloacetic transaminase type
# - Gtp : γ-GTP
# - oral : Oral Examination status
# - dental caries
# - tartar : tartar status<br>
# #### The dependent attribute or (The target variable) is :
# - smoking: NO smoking = N, YES smoking = Y

# %% [markdown]
# # Data Cleaning

# %%
# Checking the nulls
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
df.shape
# Out:
# (55692, 26)

# %%
# Droping the redundant data
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (44552, 26)

# %% [markdown]
# ##### We see that there is no nulls and no redunduncy in our dataset<br>

# %% [markdown]
# ### Checking and Removing the Outliers

# %%
df.head(n = 10).style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_bc546_row0_col1, #T_bc546_row1_col1, #T_bc546_row3_col1, #T_bc546_row4_col1, #T_bc546_row6_col1, #T_bc546_row9_col13 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_bc546_row0_col2, #T_bc546_row4_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_bc546_row0_col3, #T_bc546_row0_col7, #T_bc546_row0_col8, #T_bc546_row0_col17, #T_bc546_row0_col23, #T_bc546_row1_col3, #T_bc546_row1_col6, #T_bc546_row1_col7, #T_bc546_row1_col8, #T_bc546_row1_col17, #T_bc546_row1_col18, #T_bc546_row1_col23, #T_bc546_row2_col3, #T_bc546_row2_col4, #T_bc546_row2_col7, #T_bc546_row2_col8, #T_bc546_row2_col17, #T_bc546_row2_col23, #T_bc546_row3_col7, #T_bc546_row3_col8, #T_bc546_row3_col9, #T_bc546_row3_col10, #T_bc546_row3_col17, #T_bc546_row3_col23, #T_bc546_row4_col3, #T_bc546_row4_col7, #T_bc546_row4_col8, #T_bc546_row4_col11, #T_bc546_row4_col12, #T_bc546_row4_col15, #T_bc546_row4_col16, #T_bc546_row4_col17, #T_bc546_row4_col18
{
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_bc546_row3_col2, #T_bc546_row3_col4, #T_bc546_row5_col3, #T_bc546_row7_col2, #T_bc546_row9_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_bc546_row3_col13 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_bc546_row3_col14, #T_bc546_row8_col9 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_bc546_row3_col16 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_bc546_row3_col20 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_bc546_row4_col4, #T_bc546_row4_col5, #T_bc546_row4_col9, #T_bc546_row6_col5, #T_bc546_row9_col5 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_bc546_row4_col10, #T_bc546_row8_col10 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_bc546_row5_col4, #T_bc546_row8_col4 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_bc546_row5_col9 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_bc546_row5_col11 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_bc546_row5_col13 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_bc546_row5_col15 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_bc546_row5_col16 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_bc546_row5_col18 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_bc546_row5_col21 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_bc546_row6_col4 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_bc546_row6_col9, #T_bc546_row6_col12 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_bc546_row6_col10 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_bc546_row6_col13 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_bc546_row6_col21 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_bc546_row7_col1, #T_bc546_row9_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_bc546_row7_col12 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_bc546_row7_col16 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_bc546_row8_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_bc546_row8_col11 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_bc546_row8_col12 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_bc546_row8_col15 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_bc546_row8_col16 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_bc546_row8_col18, #T_bc546_row9_col18 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_bc546_row8_col19 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_bc546_row8_col20 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_

# %%
# Specify the columns to plot
numeric_cols = ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'AST', 'ALT', 'Gtp', 'dental caries']

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(28,8))

# Create the boxplot
df[numeric_cols].boxplot(ax=ax)

# Set the plot title
ax.set_title('Boxplot of Numerical Columns')

# Show the plot
plt.show()

# %% [markdown]
# #### Plotting each column

# %%
# Loop over each column in the DataFrame
for column_name in numeric_cols:
    
    sns.set_style("whitegrid")
    sns.kdeplot(data=df[column_name])
    plt.xlabel("Values")
    plt.title("Density plot of " + column_name)
    plt.show()

# %% [markdown]
# ##### Here we use IQR to detect the outliers and be able to remove them

# %%
# Identify outliers
outliers = []
for col in df.select_dtypes(include=['float', 'int']):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr
    outliers.extend(df[(df[col] < lower_bound) | (df[col] > upper_bound)].index)

# Drop outliers
df.drop(outliers, inplace=True)

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %% [markdown]
# - As we can see, we removed the outliers ..

# %%
df.shape
# Out:
# (21743, 26)

# %% [markdown]
# # Data Exploration and Visualization

# %%
df.describe()
# Out:
#                 age    height(cm)    weight(kg)     waist(cm)  eyesight(left)  \
# count  21743.000000  21743.000000  21743.000000  21743.000000    21743.000000
# mean      43.611737    164.439130     64.305984     80.555655        1.014165
# std       11.548174      9.108791     11.611441      8.416734        0.295231
# min       20.000000    145.000000     35.000000     58.000000        0.300000
# 25%       40.000000    155.000000     55.000000     75.000000        0.800000
# 50%       40.000000    165.000000     65.000000     80.300000        1.000000
# 75%       50.000000    170.000000     70.000000     86.000000        1.200000
# max       75.000000    185.000000    105.000000    106.000000        1.600000
#
#        eyesight(right)  hearing(left)  hearing(right)      systolic  \
# count     21743.000000        21743.0         21743.0  21743.000000
# mean          1.010054            1.0             1.0    119.589937
# std           0.294267            0.0             0.0     12.320521
# min           0.300000            1.0             1.0     85.000000
# 25%           0.800000            1.0             1.0    110.000000
# 50%           1.000000            1.0             1.0    119.000000
# 75%           1.200000            1.0             1.0    129.000000
# max           1.600000            1.0             1.0    157.000000
#
#          relaxation  fasting blood sugar   Cholesterol  triglyceride  \
# count  21743.000000         21743.000000  21743.000000  21743.000000
# mean      74.836867            94.777998    194.836821    111.487375
# std        8.783631            10.007562     32.812777     54.890567
# min       52.000000            67.000000    100.000000      8.000000
# 25%       69.000000            88.000000    172.000000     70.000000
# 50%       75.000000            94.000000    193.000000     99.000000
# 75%       80.000000           101.000000    217.000000    141.000000
# max      100.000000           126.000000    292.000000    289.000000
#
#                 HDL           LDL    hemoglobin  Urine protein  \
# count  21743.000000  21743.000000  21743.000000        21743.0
# mean      57.796624    114.856138     14.530111            1.0
# std       12.954092     30.187948      1.406954            0.0
# min       21.000000     26.000000     10.500000            1.0
# 25%       48.000000     94.000000     13.500000            1.0
# 50%       57.000000    114.000000     14.600000            1.0
# 75%       66.000000    135.000000     15.600000            1.0
# max       94.000000    202.000000     18.800000            1.0
#
#        serum creatinine           AST           ALT           Gtp  \
# count      21743.000000  21743.000000  21743.000000  21743.000000
# mean           0.876277     22.710895     21.246056     26.748563
# std            0.162856      5.845419      9.440915     15.204566
# min            0.600000      6.000000      1.000000      3.000000
# 25%            0.800000     19.000000     14.000000     16.000000
# 50%            0.900000     22.000000     19.000000     22.000000
# 75%            1.000000     26.000000     26.000000     33.000000
# max            1.200000     44.000000     55.000000     84.000000
#
#        dental caries
# count        21743.0
# mean             0.0
# std              0.0
# min              0.0
# 25%              0.0
# 50%              0.0
# 75%              0.0
# max              0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21743 entries, 0 to 44552
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               21743 non-null  object
#  1   age                  21743 non-null  int64
#  2   height(cm)           21743 non-null  int64
#  3   weight(kg)           21743 non-null  int64
#  4   waist(cm)            21743 non-null  float64
#  5   eyesight(left)       21743 non-null  float64
#  6   eyesight(right)      21743 non-null  float64
#  7   hearing(left)        21743 non-null  int64
#  8   hearing(right)       21743 non-null  int64
#  9   systolic             21743 non-null  int64
#  10  relaxation           21743 non-null  int64
#  11  fasting blood sugar  21743 non-null  int64
#  12  Cholesterol          21743 non-null  int64
#  13  triglyceride         21743 non-null  int64
#  14  HDL                  21743 non-null  int64
#  15  LDL                  21743 non-null  int64
#  16  hemoglobin           21743 non-null  float64
#  17  Urine protein        21743 non-null  int64
#  18  serum creatinine     21743 non-null  float64
#  19  AST                  21743 non-null  int64
#  20  ALT                  21743 non-null  int64
#  21  Gtp                  21743 non-null  int64
#  22  oral                 21743 non-null  object
#  23  dental caries        21743 non-null  int64
#  24  tartar               21743 non-null  object
#  25  smoking              21743 non-null  object
# dtypes: float64(5), int64(17), object(4)
# memory usage: 4.5+ MB

# %%
df.groupby('gender').size().plot(kind='pie', explode=[0,0.1], autopct='%1.1f%%', shadow=True, colors=["pink", "gray"], title="Gender")
# Out:
# <AxesSubplot: title={'center': 'Gender'}>

# %%
df.groupby('tartar').size().plot(kind='bar', title="Tartar", rot=0, xlabel='Age', ylabel='Count')
# Out:
# <AxesSubplot: title={'center': 'Tartar'}, xlabel='Age', ylabel='Count'>

# %%
fig, axes = plt.subplots(2, 3, figsize = (20, 12))
axes = axes.flatten()

sns.scatterplot(ax = axes[0], x = "weight(kg)", y = "hemoglobin",
                hue = "smoking", size = "gender", sizes=(20, 100), legend="full",
                data = df).set(title = "Relationship between 'weight(kg)' and 'hemoglobin'");

sns.scatterplot(ax = axes[1], x = "weight(kg)", y = "Cholesterol", hue = "smoking",
                size = "gender", sizes=(20, 100), legend="full",
                data = df).set(title = "Relationship between 'weight(kg)' and 'cholesterol'");

sns.scatterplot(ax = axes[2], x = "weight(kg)", y = "Urine protein", hue = "smoking",
                size = "gender", sizes=(20, 100), legend="full",
                data = df).set(title = "Relationship between 'weight(kg)' and 'urine protein'");

sns.scatterplot(ax = axes[3], x = "weight(kg)", y = "serum creatinine", hue = "smoking",
                size = "gender", sizes=(20, 100), legend="full",
                data = df).set(title = "Relationship between 'weight(kg)' and 'serum creatinine'");

sns.scatterplot(ax = axes[4], x = "weight(kg)", y = "age", hue = "smoking",
                size = "gender", sizes=(20, 100), legend="full",
                data = df).set(title = "Relationship between 'weight(kg)' and 'age'");

sns.scatterplot(ax = axes[5], x = "weight(kg)", y = "fasting blood sugar", hue = "smoking",
                size = "gender", sizes=(20, 100), legend="full",
                data = df).set(title = "Relationship between 'weight(kg)' and 'fasting blood sugar'");

# %%
df.hist(figsize = (20, 20), bins = 12, legend = False);

# %% [markdown]
# ### Observations based on the last exploration:<br>
# 1. The % of smokers within each blood pressure group is the highest among those who have hypertensive crisis and the least among those with normal blood pressure
# 2. Maximum people in the dataset have normal blood pressure
# 3. The highest number of nonsmokers is in the normal blood pressure
#     Information source: https://www.heart.org/en/health-topics/high-blood-pressure/understanding-blood-pressure-readings
# 4. HDL (the good cholesterol) is higher for non-smokers.
# 5. Average LDL (the bad cholesterol) is higher for smokers.
# 6. AST and ALT are healthy for both smoker and non-smoker groups. GTP is at risk for smokers.

# %% [markdown]
# ## Encoding and Splitting the data

# %%
lbe = LabelEncoder()
lbe.fit_transform(df["gender"])
df["gender"] = lbe.fit_transform(df["gender"])
lbe.fit_transform(df["tartar"])
df["tartar"] = lbe.fit_transform(df["tartar"])
lbe.fit_transform(df["oral"])
df["oral"] = lbe.fit_transform(df["oral"])
lbe.fit_transform(df["smoking"])
df["smoking"] = lbe.fit_transform(df["smoking"])

# %%
df.head()
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 2       1   55         170          60       80.0             0.8
# 4       0   40         155          60       86.0             1.0
# 5       1   30         180          75       85.0             1.2
# 8       0   50         150          60       85.0             0.7
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0              1.0              1               1       114          73
# 2              0.8              1               1       138          86
# 4              1.0              1               1       120          74
# 5              1.2              1               1       128          76
# 8              0.8              1               1       115          74
#
#    fasting blood sugar  Cholesterol  triglyceride  HDL  LDL  hemoglobin  \
# 0                   94          215            82   73  126        12.9
# 2                   89          242           182   55  151        15.8
# 4                   80          184            74   62  107        12.5
# 5                   95          217           199   48  129        16.2
# 8                   86          210            66   48  149        13.7
#
#    Urine protein  serum creatinine  AST  ALT  Gtp  oral  dental caries  \
# 0              1               0.7   18   19   27     0              0
# 2              1               1.0   21   16   22     0              0
# 4              1               0.6   16   14   22     0              0
# 5              1               1.2   18   27   33     0              0
# 8              1               0.8   31   31   14     0              0
#
#    tartar  smoking
# 0       1        0
# 2       0        1
# 4       0        0
# 5       1        0
# 8       0        0

# %%
# select dependent variable (label)
y = df["smoking"]

# select independent variable (estimator)
x = df.drop("smoking", axis = 1)

# %%
# Train-Test-Split   
x_train, x_test, y_train, y_test  = train_test_split(x, y,test_size=0.1,random_state=0)

# %% [markdown]
# ## Scaling the data

# %%
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Classification Models

# %% [markdown]
# ### Logistic Regression Model

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
predict = LR.predict(x_test)
print(classification_report(y_test, predict))
LRAcc = accuracy_score(predict,y_test)
print('Logistic Regression accuracy is: {:.2f}%'.format(LRAcc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1525
#            1       0.60      0.57      0.59       650
#
#     accuracy                           0.76      2175
#    macro avg       0.71      0.71      0.71      2175
# weighted avg       0.76      0.76      0.76      2175
#
# Logistic Regression accuracy is: 75.86%

# %% [markdown]
# ### Confusion Matrix for Logistic Reggression

# %%
cm = metrics.confusion_matrix(y_test, predict)
print('Confusion Matrix for Logistic Regression :\n', cm, '\n')
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.5)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix of Logistic Regression', fontsize=14)
plt.show()
# Out:
# Confusion Matrix for Logistic Regression :
#  [[1278  247]
#  [ 278  372]]

# %% [markdown]
# ### KNN Model

# %% [markdown]
# #### To find a optimum value of K we plot a graph of error rate vs K value ranging from 0 to 40

# %%
error_rate = []
for i in range(1,40):
    kNN = KNeighborsClassifier(n_neighbors=i)
    kNN.fit(x_train,y_train)
    predict_i = kNN.predict(x_test)
    error_rate.append(np.mean(predict_i != y_test))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value', fontsize=18)
plt.xlabel('K', fontsize=18)
plt.ylabel('Error Rate', fontsize=18)
plt.show()

# %% [markdown]
# - From the previous graph will observe that the minimum error rate approximately equal 20 % and this percentage occurs when K value = 34

# %%
KNN=KNeighborsClassifier(n_neighbors=27)
KNN.fit(x_train,y_train)
y_preds=KNN.predict(x_test)
print(classification_report(y_test, y_preds))
KNNAcc = accuracy_score(y_preds,y_test)
print('KNN model accuracy is: {:.2f}%'.format(KNNAcc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      1525
#            1       0.54      0.48      0.51       650
#
#     accuracy                           0.72      2175
#    macro avg       0.67      0.65      0.66      2175
# weighted avg       0.72      0.72      0.72      2175
#
# KNN model accuracy is: 72.41%

# %% [markdown]
# ### Confusion Matrix for KNN

# %%
cm = metrics.confusion_matrix(y_test, y_preds)
print('Confusion Matrix for KNN :\n', cm, '\n')
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.5)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix of KNN', fontsize=15)
plt.show()
# Out:
# Confusion Matrix for KNN :
#  [[1263  262]
#  [ 338  312]]
