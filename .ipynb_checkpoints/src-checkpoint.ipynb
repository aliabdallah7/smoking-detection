# %% [markdown]
# <p><a href="https://www.asu.edu.eg/"><img align="right" src="https://ums.asu.edu.eg/images/logo.png" width="100" /></a></p>
# <div align=left>
# <h1>
#   Body Signal of Smoking 🚭
# </h1>
#     <h5>
#         Data Analytics project
#     </h5>
# </div>
# <br>
# <br>

# %% [markdown]
# ## Introduction
# This dataset is a collection of basic health biological signal data.
# The goal is to determine the presence or absence of smoking through bio-signals.

# %% [markdown]
# ## All libraries we need through the notebook

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# to ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading the dataset

# %%
df = pd.read_csv('smoking.csv')
df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0              1               1  ...        12.9
# 1              0.6              1               1  ...        12.7
# 2              0.8              1               1  ...        15.8
# 3              1.5              1               1  ...        14.7
# 4              1.0              1               1  ...        12.5
#
#    Urine protein  serum creatinine  AST  ALT  Gtp  oral  dental caries  \
# 0              1               0.7   18   19   27     Y              0
# 1              1               0.6   22   19   18     Y              0
# 2              1               1.0   21   16   22     Y              0
# 3              1               1.0   19   26   18     Y              0
# 4              1               0.6   16   14   22     Y              0
#
#    tartar  smoking
# 0       Y        N
# 1       Y        N
# 2       N        Y
# 3       Y        N
# 4       N        N
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental caries',
#        'tartar', 'smoking'],
#       dtype='object')

# %% [markdown]
# ####
# #### We see thet the dataset attributes are divided into dependent and independent attributes.
# #### The inedependent attributes are :
# - ID : index
# - gender
# - age : 5-years gap
# - height(cm)
# - weight(kg)
# - waist(cm) : Waist circumference length
# - eyesight(left)
# - eyesight(right)
# - hearing(left)
# - hearing(right)
# - systolic : Blood pressure (measures the pressure in your arteries when your heart beats)
# - relaxation : Blood pressure
# - fasting blood sugar
# - Cholesterol : total
# - triglyceride
# - HDL : cholesterol type
# - LDL : cholesterol type
# - hemoglobin
# - Urine protein
# - serum creatinine
# - AST : glutamic oxaloacetic transaminase type
# - ALT : glutamic oxaloacetic transaminase type
# - Gtp : γ-GTP
# - oral : Oral Examination status
# - dental caries
# - tartar : tartar status<br>
# #### The dependent attribute or (The target variable) is :
# - smoking: NO smoking = N, YES smoking = Y

# %% [markdown]
# # Data Cleaning

# %%
# Checking the nulls
df.isnull().sum()
# Out:
# ID                     0
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
df.shape
# Out:
# (55692, 27)

# %%
# Droping the redundant data
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (55692, 27)

# %% [markdown]
# ##### We see that there is no nulls and no redunduncy in our dataset<br>

# %% [markdown]
# ### Checking and Removing the Outliers

# %%
df.head(n = 10).style.background_gradient(cmap = "Blues")
# Out:
# <style type="text/css">
# #T_7555f_row0_col0, #T_7555f_row0_col4, #T_7555f_row0_col8, #T_7555f_row0_col9, #T_7555f_row0_col18, #T_7555f_row0_col24, #T_7555f_row1_col4, #T_7555f_row1_col7, #T_7555f_row1_col8, #T_7555f_row1_col9, #T_7555f_row1_col18, #T_7555f_row1_col19, #T_7555f_row1_col24, #T_7555f_row2_col4, #T_7555f_row2_col5, #T_7555f_row2_col8, #T_7555f_row2_col9, #T_7555f_row2_col18, #T_7555f_row2_col24, #T_7555f_row3_col8, #T_7555f_row3_col9, #T_7555f_row3_col10, #T_7555f_row3_col11, #T_7555f_row3_col18, #T_7555f_row3_col24, #T_7555f_row4_col4, #T_7555f_row4_col8, #T_7555f_row4_col9, #T_7555f_row4_col12, #T_7555f_row4_col13, #T_7555f_row4_col16, #T_7555f_row4_col17, #T_7555f_row4_col18, #T_7555f_row4_col19, #T_7555f_row4_col20, #T_7555f_row4_col21, #T_7555f_row4_col24, #T_7555f_row5_col2, #T_7555f_row5_col8, #T_7555f_row5_col9, #T_7555f_row5_col18, #T_7555f_row5_col24, #T_7555f_row6_col4, #T_7555f_row6_col8, #T_7555f_row6_col9, #T_7555f_row6_col18, #T_7555f_row7_col8, #T_7555f_row7_col9, #T_7555f_row7_col15, #T_7555f_row7_col18, #T_7555f_row7_col24, #T_7555f_row8_col3, #T_7555f_row8_col4, #T_7555f_row8_col6, #T_7555f_row8_col8, #T_7555f_row8_col9, #T_7555f_row8_col14, #T_7555f_row8_col18, #T_7555f_row8_col22, #T_7555f_row8_col24, #T_7555f_row9_col8, #T_7555f_row9_col9, #T_7555f_row9_col18, #T_7555f_row9_col24 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7555f_row0_col2, #T_7555f_row1_col2, #T_7555f_row3_col2, #T_7555f_row4_col0, #T_7555f_row4_col2, #T_7555f_row6_col2, #T_7555f_row9_col14 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_7555f_row0_col3, #T_7555f_row4_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_7555f_row0_col5, #T_7555f_row0_col14 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_7555f_row0_col6, #T_7555f_row5_col6, #T_7555f_row7_col6 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_7555f_row0_col7, #T_7555f_row4_col7, #T_7555f_row5_col11, #T_7555f_row6_col7, #T_7555f_row7_col7, #T_7555f_row9_col7 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_7555f_row0_col10 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_7555f_row0_col11 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_7555f_row0_col12, #T_7555f_row6_col12, #T_7555f_row9_col12 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_7555f_row0_col13 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_7555f_row0_col15, #T_7555f_row2_col2, #T_7555f_row3_col6, #T_7555f_row3_col7, #T_7555f_row3_col13, #T_7555f_row3_col16, #T_7555f_row5_col3, #T_7555f_row6_col17, #T_7555f_row6_col24, #T_7555f_row7_col4, #T_7555f_row7_col5, #T_7555f_row7_col10, #T_7555f_row7_col11, #T_7555f_row7_col12, #T_7555f_row7_col14, #T_7555f_row7_col19, #T_7555f_row7_col20, #T_7555f_row7_col21, #T_7555f_row7_col22, #T_7555f_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7555f_row0_col16, #T_7555f_row9_col16 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_7555f_row0_col17, #T_7555f_row0_col21, #T_7555f_row1_col21 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_7555f_row0_col19, #T_7555f_row6_col19 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_7555f_row0_col20, #T_7555f_row5_col20 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_7555f_row0_col22, #T_7555f_row3_col20 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_7555f_row1_col0, #T_7555f_row9_col13 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_7555f_row1_col3, #T_7555f_row3_col4, #T_7555f_row6_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7555f_row1_col5 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7555f_row1_col6, #T_7555f_row2_col6 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_7555f_row1_col10, #T_7555f_row5_col15, #T_7555f_row8_col15 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_7555f_row1_col11 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_7555f_row1_col12 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_7555f_row1_col13 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7555f_row1_col14, #T_7555f_row5_col13 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_7555f_row1_col15, #T_7555f_row3_col12 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_7555f_row1_col16 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_7555f_row1_col17 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7555f_row1_col20 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_7555f_row1_col22, #T_7555f_row3_col22, #T_7555f_row4_col14 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7555f_row2_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_7555f_row2_col3, #T_7555f_row5_col7 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_7555f_row2_col7, #T_7555f_row8_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_7555f_row2_col10, #T_7555f_row4_col15 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_7555f_row2_col11 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_7555f_row2_col12 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_7555f_row2_col13, #T_7555f_row6_col16 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_7555f_row2_col14, #T_7555f_row2_col19, #T_7555f_row3_col19 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_7555f_row2_col15, #T_7555f_row6_col15 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_7555f_row2_col16 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_7555f_row2_col17 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_7555f_row2_col20, #T_7555f_row5_col21, #T_7555f_row6_col20, #T_7555f_row6_col21, #T_7555f_row7_col16 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_7555f_row2_col21 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7555f_row2_col22, #T_7555f_row4_col22 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_7555f_row3_col0, #T_7555f_row8_col21 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_7555f_row3_col3, #T_7555f_row3_col5, #T_7555f_row5_col0, #T_7555f_row5_col4, #T_7555f_row7_col3, #T_7555f_row9_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_7555f_row3_col14 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_7555f_row3_col15, #T_7555f_row8_col10 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_7555f_row3_col17 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_7555f_row3_col21 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_7555f_row4_col5, #T_7555f_row4_col6, #T_7555f_row4_col10, #T_7555f_row6_col6, #T_7555f_row9_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_7555f_row4_col11, #T_7555f_row8_col11 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_7555f_row5_col5, #T_7555f_row8_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_7555f_row5_col10 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_7555f_row5_col12 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_7555f_row5_col14 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_7555f_row5_col16 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_7555f_row5_col17 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_7555f_row5_col19 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_7555f_row5_col22 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_7555f_row6_col0, #T_7555f_row7_col2, #T_7555f_row9_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_7555f_row6_col5 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_7555f_row6_col10, #T_7555f_row6_col13 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_7555f_row6_col11 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_7555f_row6_col14 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7555f_row6_col22 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7555f_row7_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_7555f_row7_col13 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_7555f_row7_col17 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_7555f_row8_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_7555f_row8_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_7555f_row8_col12

# %%
# Specify the columns to plot
numeric_cols = ['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'AST', 'ALT', 'Gtp', 'dental caries']

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(28,8))

# Create the boxplot
df[numeric_cols].boxplot(ax=ax)

# Set the plot title
ax.set_title('Boxplot of Numerical Columns')

# Show the plot
plt.show()

# %%
# Loop over each column in the DataFrame
for column_name in numeric_cols:
    
    sns.set_style("whitegrid")
    sns.kdeplot(data=df[column_name])
    plt.xlabel("Values")
    plt.title("Density plot of " + column_name)
    plt.show()

# %% [markdown]
# ##### Here we use IQR to detect the outliers and be able to remove them

# %%
for x in numeric_cols:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25
 
    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)
 
    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
df.isnull().sum()
# Out:
# ID                         0
# gender                     0
# age                      295
# height(cm)               249
# weight(kg)               198
# waist(cm)                496
# eyesight(left)          1314
# eyesight(right)         1357
# hearing(left)           1425
# hearing(right)          1456
# systolic                 685
# relaxation               706
# fasting blood sugar     3298
# Cholesterol              605
# triglyceride            2256
# HDL                     1011
# LDL                      634
# hemoglobin               669
# Urine protein           3093
# serum creatinine           0
# AST                     3699
# ALT                     3710
# Gtp                     5019
# oral                       0
# dental caries          11881
# tartar                     0
# smoking                    0
# dtype: int64

# %% [markdown]
# - As we can see, we removed the outliers .. now we must replace these null values with median

# %%
# Dropping The Rows That Have Null Values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                     0
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
df.shape
# Out:
# (28513, 27)

# %% [markdown]
# # Data Exploration and Visualization

# %%
df.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  28513.000000  28513.000000  28513.000000  28513.000000  28513.000000
# mean   27862.479466     43.696033    164.249816     64.132150     80.438372
# std    16073.110073     11.494061      9.119491     11.643722      8.438047
# min        0.000000     20.000000    145.000000     35.000000     58.000000
# 25%    14014.000000     40.000000    155.000000     55.000000     74.500000
# 50%    27962.000000     40.000000    165.000000     65.000000     80.000000
# 75%    41779.000000     50.000000    170.000000     70.000000     86.000000
# max    55691.000000     75.000000    185.000000    105.000000    106.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    28513.000000     28513.000000        28513.0         28513.0
# mean         1.013885         1.008382            1.0             1.0
# std          0.295411         0.293706            0.0             0.0
# min          0.300000         0.300000            1.0             1.0
# 25%          0.800000         0.800000            1.0             1.0
# 50%          1.000000         1.000000            1.0             1.0
# 75%          1.200000         1.200000            1.0             1.0
# max          1.600000         1.600000            1.0             1.0
#
#            systolic  ...  triglyceride           HDL           LDL  \
# count  28513.000000  ...  28513.000000  28513.000000  28513.000000
# mean     119.544313  ...    111.208010     57.861326    114.760565
# std       12.350543  ...     54.768955     12.969910     30.020007
# min       85.000000  ...      8.000000     21.000000     26.000000
# 25%      110.000000  ...     70.000000     48.000000     94.000000
# 50%      119.000000  ...     99.000000     57.000000    113.000000
# 75%      129.000000  ...    140.000000     66.000000    135.000000
# max      157.000000  ...    289.000000     94.000000    202.000000
#
#          hemoglobin  Urine protein  serum creatinine           AST  \
# count  28513.000000        28513.0      28513.000000  28513.000000
# mean      14.492894            1.0          0.872791     22.516045
# std        1.427702            0.0          0.196874      5.629155
# min       10.300000            1.0          0.100000      6.000000
# 25%       13.400000            1.0          0.700000     18.000000
# 50%       14.600000            1.0          0.900000     22.000000
# 75%       15.600000            1.0          1.000000     26.000000
# max       19.100000            1.0         10.000000     41.000000
#
#                 ALT           Gtp  dental caries
# count  28513.000000  28513.000000        28513.0
# mean      21.029390     26.338723            0.0
# std        9.294486     14.842243            0.0
# min        1.000000      3.000000            0.0
# 25%       14.000000     16.000000            0.0
# 50%       19.000000     22.000000            0.0
# 75%       26.000000     33.000000            0.0
# max       55.000000     82.000000            0.0
#
# [8 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28513 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   28513 non-null  int64
#  1   gender               28513 non-null  object
#  2   age                  28513 non-null  float64
#  3   height(cm)           28513 non-null  float64
#  4   weight(kg)           28513 non-null  float64
#  5   waist(cm)            28513 non-null  float64
#  6   eyesight(left)       28513 non-null  float64
#  7   eyesight(right)      28513 non-null  float64
#  8   hearing(left)        28513 non-null  float64
#  9   hearing(right)       28513 non-null  float64
#  10  systolic             28513 non-null  float64
#  11  relaxation           28513 non-null  float64
#  12  fasting blood sugar  28513 non-null  float64
#  13  Cholesterol          28513 non-null  float64
#  14  triglyceride         28513 non-null  float64
#  15  HDL                  28513 non-null  float64
#  16  LDL                  28513 non-null  float64
#  17  hemoglobin           28513 non-null  float64
#  18  Urine protein        28513 non-null  float64
#  19  serum creatinine     28513 non-null  float64
#  20  AST                  28513 non-null  float64
#  21  ALT                  28513 non-null  float64
#  22  Gtp                  28513 non-null  float64
#  23  oral                 28513 non-null  object
#  24  dental caries        28513 non-null  float64
#  25  tartar               28513 non-null  object
#  26  smoking              28513 non-null  object
# dtypes: float64(22), int64(1), object(4)
# memory usage: 6.1+ MB

# %%
df.groupby('gender').size().plot(kind='pie', explode=[0,0.1], autopct='%1.1f%%', shadow=True, colors=["grey", "pink"], title="Gender")
# Out:
# <AxesSubplot: title={'center': 'Gender'}>

# %%
df.groupby('smoking').size().plot(kind='pie', explode=[0,0.1], autopct='%1.1f%%', shadow=True, colors=["yellow", "red"], title="Gender")
# Out:
# <AxesSubplot: title={'center': 'Gender'}>

# %%
df.groupby('tartar').size().plot(kind='bar', title="Tartar", rot=0, xlabel='Age', ylabel='Count')
# Out:
# <AxesSubplot: title={'center': 'Age'}, xlabel='Age', ylabel='Count'>

# %%
pd.crosstab(df['gender'], df['dental caries'], normalize = True).plot(kind = "line", stacked=True);
